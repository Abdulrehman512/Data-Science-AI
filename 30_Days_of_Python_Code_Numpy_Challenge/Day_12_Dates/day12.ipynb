# %% [markdown]
# ### Q1:

# %% [markdown]
# ![1.png](attachment:1.png)

# %%
import numpy as np
 
 
arr = np.arange('2024-01-01', '2024-02', dtype='datetime64[D]')[::7]
print(arr)
# Out:
# ['2024-01-01' '2024-01-08' '2024-01-15' '2024-01-22' '2024-01-29']

# %% [markdown]
# ### Q2:

# %% [markdown]
# ![2.png](attachment:2.png)

# %%
import numpy as np
 
 
dates = np.arange('2025-01', '2025-02', dtype='datetime64[D]')
result = np.c_[dates, dates + np.timedelta64(3, 'D')]
 
print(result)
# Out:
# [['2025-01-01' '2025-01-04']
#  ['2025-01-02' '2025-01-05']
#  ['2025-01-03' '2025-01-06']
#  ['2025-01-04' '2025-01-07']
#  ['2025-01-05' '2025-01-08']
#  ['2025-01-06' '2025-01-09']
#  ['2025-01-07' '2025-01-10']
#  ['2025-01-08' '2025-01-11']
#  ['2025-01-09' '2025-01-12']
#  ['2025-01-10' '2025-01-13']
#  ['2025-01-11' '2025-01-14']
#  ['2025-01-12' '2025-01-15']
#  ['2025-01-13' '2025-01-16']
#  ['2025-01-14' '2025-01-17']
#  ['2025-01-15' '2025-01-18']
#  ['2025-01-16' '2025-01-19']
#  ['2025-01-17' '2025-01-20']
#  ['2025-01-18' '2025-01-21']
#  ['2025-01-19' '2025-01-22']
#  ['2025-01-20' '2025-01-23']
#  ['2025-01-21' '2025-01-24']
#  ['2025-01-22' '2025-01-25']
#  ['2025-01-23' '2025-01-26']
#  ['2025-01-24' '2025-01-27']
#  ['2025-01-25' '2025-01-28']
#  ['2025-01-26' '2025-01-29']
#  ['2025-01-27' '2025-01-30']
#  ['2025-01-28' '2025-01-31']
#  ['2025-01-29' '2025-02-01']
#  ['2025-01-30' '2025-02-02']
#  ['2025-01-31' '2025-02-03']]

# %% [markdown]
# ### Q3:

# %% [markdown]
# ![3.png](attachment:3.png)

# %%
import numpy as np
 
 
arr = np.arange('2024-01-01', '2024-02-01', dtype='datetime64[D]')
arr = arr.reshape(-1, 1)
 
print(arr)
# Out:
# [['2024-01-01']
#  ['2024-01-02']
#  ['2024-01-03']
#  ['2024-01-04']
#  ['2024-01-05']
#  ['2024-01-06']
#  ['2024-01-07']
#  ['2024-01-08']
#  ['2024-01-09']
#  ['2024-01-10']
#  ['2024-01-11']
#  ['2024-01-12']
#  ['2024-01-13']
#  ['2024-01-14']
#  ['2024-01-15']
#  ['2024-01-16']
#  ['2024-01-17']
#  ['2024-01-18']
#  ['2024-01-19']
#  ['2024-01-20']
#  ['2024-01-21']
#  ['2024-01-22']
#  ['2024-01-23']
#  ['2024-01-24']
#  ['2024-01-25']
#  ['2024-01-26']
#  ['2024-01-27']
#  ['2024-01-28']
#  ['2024-01-29']
#  ['2024-01-30']
#  ['2024-01-31']]

# %% [markdown]
# ### Q4:

# %% [markdown]
# ![4.png](attachment:4.png)

# %%
import numpy as np
 
 
arr = np.arange('2024-01', '2025-01', dtype='datetime64[M]')
arr = arr.reshape(-1, 3)
 
print(arr)
# Out:
# [['2024-01' '2024-02' '2024-03']
#  ['2024-04' '2024-05' '2024-06']
#  ['2024-07' '2024-08' '2024-09']
#  ['2024-10' '2024-11' '2024-12']]

# %% [markdown]
# ### Q5:

# %% [markdown]
# ![5.png](attachment:5.png)

# %%
import numpy as np
 
 
print(np.datetime64('today'))
# Out:
# 2024-02-11

# %% [markdown]
# ### Q6:

# %% [markdown]
# ![6.png](attachment:6.png)

# %%
import numpy as np
 
 
dates = np.arange('2025-01-01', '2025-01-10', dtype='datetime64[D]')
result = np.sum(np.is_busday(dates))
 
print(result)
# Out:
# 7
